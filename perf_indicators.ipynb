# %%
# Import the required libraries and dependencies
# Import Pandas library 
import pandas as pd

from scripts.perf_indicators import get_crypto_coins,get_pct_change,get_cumulative_prod,get_standard_deviation,get_sharpe_rations

# %%
# calling a function in a py script.
# reading the csv file and capturing the coins into a dataframe
crypto_coins_df = get_crypto_coins()

# %%
# calling a function in a py script.
# capturing the coins daily returns into a dataframe
crypto_daily_returns_df = get_pct_change(crypto_coins_df)

# %%
# calling a function in a py script.
# capturing the coins cumulative product into a dataframe
get_cumulative_prod_df = get_cumulative_prod(crypto_daily_returns_df)

# %%
# calling a function in a py script.
# capturing the coins Standard deviation into a dataframe
standard_deviation_df = get_standard_deviation(crypto_daily_returns_df)

# %%
# calling a function in a py script.
# capturing the coins beta (60 day rolling covarience ) into a dataframe
rolling_60_beta_df = get_sharpe_rations(standard_deviation_df,crypto_daily_returns_df)

# %%
display(get_cumulative_prod_df)
# Out:
#             bitcoin prices  ethereum prices  binancecoin prices  \
# time
# 2013-04-28             NaN              NaN                 NaN
# 2013-04-29        1.049224              NaN                 NaN
# 2013-04-30        1.000000              NaN                 NaN
# 2013-05-01        0.864745              NaN                 NaN
# 2013-05-02        0.764449              NaN                 NaN
# ...                    ...              ...                 ...
# 2021-05-10      430.258140      1388.870706         6171.448542
# 2021-05-11      413.168275      1405.417624         5916.883531
# 2021-05-12      420.761067      1477.172179         6271.644843
# 2021-05-13      369.584347      1379.460840         5617.084200
# 2021-05-14      369.348081      1324.450878         5312.343733
#
#             cardano prices  ripple prices  dogecoin prices  tether prices  \
# time
# 2013-04-28             NaN            NaN              NaN            NaN
# ...
